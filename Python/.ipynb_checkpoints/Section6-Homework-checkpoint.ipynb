# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
#plt.rcParams['figure.figsize'] = 12,6
sns.set_style("darkgrid")

# %%
import pandas as pd

# %%
movies = pd.read_csv("P4-Section6-Homework-Dataset.csv")

# %%
movies
# Out:
#     Day of Week                                Director   Genre  \
# 0        Friday                               Brad Bird  action
# 1        Friday                             Scott Waugh  action
# 2        Friday                          Patrick Hughes  action
# 3        Friday                 Phil Lord, Chris Miller  comedy
# 4        Friday                         Roland Emmerich  action
# ..          ...                                     ...     ...
# 603   Wednesday                        William Friedkin  horror
# 604   Wednesday                            George Lucas  action
# 605      Friday                           James Cameron  sci-fi
# 606   Wednesday                           James Cameron   drama
# 607      Friday  George Cukor, Victor Fleming, Sam Wood   drama
#
#             Movie Title Release Date               Studio  \
# 0          Tomorrowland   22/05/2015  Buena Vista Studios
# 1        Need for Speed   14/03/2014  Buena Vista Studios
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Day of Week             608 non-null    object
#  1   Director                608 non-null    object
#  2   Genre                   608 non-null    object
#  3   Movie Title             608 non-null    object
#  4   Release Date            608 non-null    object
#  5   Studio                  608 non-null    object
#  6   Adjusted Gross ($mill)  608 non-null    object
#  7   Budget ($mill)          608 non-null    float64
#  8   Gross ($mill)           608 non-null    object
#  9   IMDb Rating             608 non-null    float64
#  10  MovieLens Rating        608 non-null    float64
#  11  Overseas ($mill)        608 non-null    object
#  12  Overseas%               608 non-null    float64
#  13  Profit ($mill)          608 non-null    object
# ...

# %%
movies.Genre = movies.Genre.astype('category')

# %%
movies.Genre.cat.categories
# Out:
# Index(['action', 'adventure', 'animation', 'biography', 'comedy', 'crime',
#        'documentary', 'drama', 'fantasy', 'horror', 'musical', 'mystery',
#        'romance', 'sci-fi', 'thriller'],
#       dtype='object')

# %%
Filter_Genre = (movies.Genre == "action") | (movies.Genre == "comedy") | (movies.Genre == "adventure") | (movies.Genre == "animation") | (movies.Genre == "drama")

# %%
Filter_Genre
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 603    False
# 604     True
# 605    False
# 606    False
# 607    False
# Name: Genre, Length: 608, dtype: bool

# %%
movies[Filter_Genre]
# Out:
#        WeekDay                                Director      Genre  \
# 0       Friday                               Brad Bird     action
# 1       Friday                             Scott Waugh     action
# 2       Friday                          Patrick Hughes     action
# 3       Friday                 Phil Lord, Chris Miller     comedy
# 4       Friday                         Roland Emmerich     action
# ..         ...                                     ...        ...
# 600     Friday                        Steven Spielberg  adventure
# 602    Tuesday                       Richard Fleischer  adventure
# 604  Wednesday                            George Lucas     action
# 606  Wednesday                           James Cameron      drama
# 607     Friday  George Cukor, Victor Fleming, Sam Wood      drama
#
#                            Movie ReleaseDate               Studio  \
# 0                   Tomorrowland  22/05/2015  Buena Vista Studios
# ...

# %%
# Out:
# Index(['action', 'adventure', 'animation', 'biography', 'comedy', 'crime',
#        'documentary', 'drama', 'fantasy', 'horror', 'musical', 'mystery',
#        'romance', 'sci-fi', 'thriller'],
#       dtype='object')

# %%
movies.columns
# Out:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Budget ($mill)', 'Gross ($mill)',
#        'IMDb Rating', 'MovieLens Rating', 'Overseas ($mill)', 'Overseas%',
#        'Profit ($mill)', 'Profit%', 'Runtime (min)', 'US ($mill)',
#        'Gross % US'],
#       dtype='object')

# %%
movies.columns = ['WeekDay', 'Director', 'Genre', 'Movie', 'ReleaseDate',
       'Studio', 'AdjustedGross', 'Budget', 'Gross',
       'ImdbRating', 'MovieLensRating', 'Overseas', 'OverseasPercent',
       'Profit', 'ProfitPercent', 'Runtime', 'US',
       'GrossPercentUS']

# %%
movies2 = movies[Filter_Genre]

# %%
movies2
# Out:
#        WeekDay                                Director      Genre  \
# 0       Friday                               Brad Bird     action
# 1       Friday                             Scott Waugh     action
# 2       Friday                          Patrick Hughes     action
# 3       Friday                 Phil Lord, Chris Miller     comedy
# 4       Friday                         Roland Emmerich     action
# ..         ...                                     ...        ...
# 600     Friday                        Steven Spielberg  adventure
# 602    Tuesday                       Richard Fleischer  adventure
# 604  Wednesday                            George Lucas     action
# 606  Wednesday                           James Cameron      drama
# 607     Friday  George Cukor, Victor Fleming, Sam Wood      drama
#
#                            Movie ReleaseDate               Studio  \
# 0                   Tomorrowland  22/05/2015  Buena Vista Studios
# ...

# %%
# Filter the dataframe by studio
movies3 = movies2[(movies2.Studio == 'Buena Vista Studios') | (movies2.Studio == 'Fox') | (movies2.Studio == 'Paramount Pictures') | (movies2.Studio == 'Sony') | (movies2.Studio == 'Universal') | (movies2.Studio == 'WB')]

# %%
fig1 = sns.boxplot(data=movies3, x=movies3.Genre, y=movies3.GrossPercentUS, order=movies3.Genre.unique(), \
            color="#dfdde5", showfliers=False)

sns.stripplot(x='Genre', y='GrossPercentUS', data=movies3, jitter=True, \
              size=6, linewidth=0, hue = 'Studio', alpha=0.7, 
             order=movies3.Genre.unique())

fig1.axes.set_title('Domestic Gross % by Genre',fontsize=30)
fig1.set_xlabel('Genre',fontsize=20)
fig1.set_ylabel('Gross % US',fontsize=20)

# Define where to place the legend
fig1.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
