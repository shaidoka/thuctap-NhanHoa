# %%
import pandas as pd
import os

# %%
movies = pd.read_csv("P4-Movie-Ratings.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', \
                 'BudgetMilions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMilions  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMilions   559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMilions   559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMilions   559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 15.6 KB

# %%
movies
# Out:
#      Film      Genre  CriticRating  AudienceRating  BudgetMilions  Year
# 0    2009     Comedy            87              81              8  2009
# 1    2008  Adventure             9              44            105  2008
# 2    2009     Action            30              52             20  2009
# 3    2010  Adventure            93              84             18  2010
# 4    2009     Comedy            55              70             20  2009
# ..    ...        ...           ...             ...            ...   ...
# 554  2011     Comedy            26              36             50  2011
# 555  2009     Comedy            68              52             18  2009
# 556  2007   Thriller            89              73             65  2007
# 557  2009     Action            90              87             24  2009
# 558  2011     Comedy            14              42             80  2011
#
# [559 rows x 6 columns]

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMilions
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='hex')

# %%
m1 = sns.distplot(movies.AudienceRating, bins=15)

# %%
sns.set_style("darkgrid")
m2 = sns.distplot(movies.CriticRating, bins=15)

# %%
sns.set_style("white")
n1 = plt.hist(movies.AudienceRating, bins=15)

# %% [markdown]
# ---

# %%
# Stacked Histogram

# %%
sns.set_style("darkgrid")
plt.hist(movies[movies.Genre == "Action"].BudgetMilions, bins=15)
plt.hist(movies[movies.Genre == "Drama"].BudgetMilions, bins=15)
plt.hist(movies[movies.Genre == "Thriller"].BudgetMilions, bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre == "Action"].BudgetMilions, movies[movies.Genre == "Drama"].BudgetMilions], bins=15, stacked=True)
plt.show()

# %%
plt.hist([movies[movies.Genre == "Action"].BudgetMilions, movies[movies.Genre == "Drama"].BudgetMilions], bins=15)
plt.show()

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMilions)
    mylabels.append(gen)

h = plt.hist(list1, bins=15, stacked=True, label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %%
# KDE plot

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', \
                 fit_reg=False, hue='Genre', height=7, aspect=1)

# %%
k1 = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRating, \
                shade=True, shade_lowest=False, cmap='Reds')

# %%
k1 = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRating, \
                shade=True, shade_lowest=False, cmap='Reds')

# Tip: 
k1b = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRating, \
                 cmap='Reds')

# %% [markdown]
# ---

# %%
# Working with subplots()

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
k1 = sns.kdeplot

# %%
k1 = sns.kdeplot(x = movies.BudgetMilions, y = movies.AudienceRating)

# %%
f, axes = plt.subplots(1,2)
k1 = sns.kdeplot(x = movies.BudgetMilions, y = movies.AudienceRating, ax=axes[0])
k2 = sns.kdeplot(x = movies.BudgetMilions, y = movies.CriticRating, ax=axes[1])

# %%
f, axes = plt.subplots(1,2, sharex=True, sharey=True)
k1 = sns.kdeplot(x = movies.BudgetMilions, y = movies.AudienceRating, ax=axes[0])
k2 = sns.kdeplot(x = movies.BudgetMilions, y = movies.CriticRating, ax=axes[1])

# %% [markdown]
# ---

# %%
# ViolunPlots

# %%
z = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %% [markdown]
# ---

# %%
# Creating a Facet Grid
q = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.hist, 'BudgetMilions')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='Black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)

# %% [markdown]
# ---

# %%
# Controlling Axes and Adding Diagonals
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='Black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)
g.set(xlim=(0,100), ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c="gray", ls="--")

g.add_legend()

# %% [markdown]
# ---

# %%
# Building Dashboard

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
plt.rcParams['figure.figsize'] = 15,15

# %%
f, axes = plt.subplots(2, 2)
k1 = sns.kdeplot(x = movies.BudgetMilions, y = movies.AudienceRating, ax=axes[0,0])
k2 = sns.kdeplot(x = movies.BudgetMilions, y = movies.CriticRating, ax=axes[0,1])

k3 = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                  x='Year', y='CriticRating', ax=axes[1,0])
#k4 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, \
#                shade=True, shade_lowest=False, cmap='Reds', \
#                ax=axes[1,1])
#k4b = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, \
#                 cmap='Reds', ax=axes[1,1])
axes[1,1].hist(movies.CriticRating, bins=15)

plt.show()

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
plt.rcParams['figure.figsize'] = 15,15

# %%
sns.set_style("darkgrid", {"axes.facecolor": "gray"})
f, axes = plt.subplots(2, 2)
k1 = sns.kdeplot(x = movies.BudgetMilions, y = movies.AudienceRating, \
                 shade=True, shade_lowest=True, cmap='coolwarm', \
                 ax=axes[0,0])
k1b = sns.kdeplot(x = movies.BudgetMilions, y = movies.AudienceRating, \
                 cmap='Greens', ax=axes[0,0])

k2 = sns.kdeplot(x = movies.BudgetMilions, y = movies.CriticRating, \
                 shade=True, shade_lowest=True, cmap='inferno', \
                 ax=axes[0,1])
k1b = sns.kdeplot(x = movies.BudgetMilions, y = movies.CriticRating, \
                 cmap='cool', ax=axes[0,1])

k3 = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                  x='Year', y='CriticRating', ax=axes[1,0])
k4 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, \
                shade=True, shade_lowest=False, cmap='Reds', \
                ax=axes[1,1])
k4b = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, \
                 cmap='Reds', ax=axes[1,1])

# %% [markdown]
# ---

# %%
# Thematics edit
